# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("df3")
df.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df.plot.scatter(x='a', y='b', c='red', figsize=(10,4), s=50, edgecolor='black')
# Out:
# D:\apps\anaconda\files\lib\site-packages\pandas\plotting\_matplotlib\core.py:1114: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
# <Axes: xlabel='a', ylabel='b'>

# %%
df.a.plot.hist(edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.a.plot.hist(bins=30, color='red', alpha=0.5, edgecolor='white')
# Out:
# <Axes: ylabel='Frequency'>

# %%
a_b = df[['a', 'b']]
a_b.plot.box(color='red',)
# a_b
# Out:
# <Axes: >

# %%
df.d.plot.kde(color='red', alpha=0.5)
# Out:
# <Axes: ylabel='Density'>

# %%
df.d.plot.kde(color='red', lw=3, linestyle='dashed')
# Out:
# <Axes: ylabel='Density'>

# %%
df.iloc[0:30].plot.area(alpha=0.4)
# Out:
# <Axes: >

# %%
df.iloc[0:30].plot.area(alpha=0.4)
plt.legend(bbox_to_anchor=(1.0, 0.5), loc='center left')
